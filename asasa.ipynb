# %%
import numpy as np
import pandas as pd

# %%
Rentaldata = pd.read_csv('data_rent_extended.csv')

# %%
Rentaldata.head(50)
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 0              0           0
# 1              1           1
# 2              2           2
# 3              3           3
# 4              4           4
# 5              5           5
# 6              6           6
# 7              7           7
# 8              8           8
# 9              9           9
# 10            10          10
# 11            11          11
# 12            12          12
# 13            13          13
# 14            14          14
# 15            15          15
# 16            16          16
# 17            17          17
# 18            18          18
# 19            19          19
# 20            20          20
# 21            21          21
# 22            22          22
# 23            23          23
# 24            24          24
# 25            25          25
# 26            26          26
# 27            27          27
# 28            28          28
# 29            29          29
# 30            30          30
# 31            31          31
# 32            32          32
# 33            33          33
# 34            34          34
# 35            35          35
# 36            36          36
# 37            37          37
# 38            38          38
# 39            39          39
# 40            40          40
# 41            41          41
# 42            42          42
# 43            43          43
# 44            44          44
# 45            45          45
# 46            46          46
# 47            47          47
# 48            48          48
# 49            49          49
#
#                                              Location     Price  Serviced  \
# 0   White Oak Estate, Ologolo Opp. Agungi, Ologolo...   5000000         0
# 1       Hrc Estate Beside Vgc Estate, Vgc Lekki Lagos   5000000         0
# 2                            Osapa London Lekki Lagos   3500000         1
# 3                                 Ologolo Lekki Lagos   2700000         1
# 4                        Mojisola Onikoyi Ikoyi Lagos   5000000         1
# 5                                 Chevron Lekki Lagos   4000000         1
# 6        Banana Island Road Banana Island Ikoyi Lagos   6500000         1
# 7                      Banana Island Road Ikoyi Lagos   6500000         1
# 8                                 Chevron Lekki Lagos   3500000         1
# 9                          Lekki Palm City Ajah Lagos   4000000         0
# 10      Banana Island Ikoyi Banana Island Ikoyi Lagos  45000000         0
# 11      Admiralty Way Lekki Lekki Phase 1 Lekki Lagos  15000000         0
# 12                  Lekki Palm City Estate Ajah Lagos   2500000         0
# 13                                 Agungi Lekki Lagos   6500000         0
# 14                                  Ikate Lekki Lagos   8000000         1
# 15                                Chevron Lekki Lagos   5000000         0
# 16                           Osapa London Lekki Lagos   6000000         0
# 17                              Victoria Island Lagos  10000000         1
# 18                        Second Tollgate Lekki Lagos   4000000         1
# 19                          Banana Island Ikoyi Lagos  12000000         0
# 20                            Iwaya, Onike Yaba Lagos   1400000         0
# 21              Chevron Toll Gate Chevron Lekki Lagos   3000000         1
# 22                          Lekki Phase 1 Lekki Lagos   1500000         1
# 23                 Abuleoja Yaba Abule Oja Yaba Lagos   1100000         1
# 24                       Iwaya Onike Iwaya Yaba Lagos   1400000         0
# 25            Lekki Phase 1 Lekki Phase 1 Lekki Lagos  16000000         1
# 26                                Chevron Lekki Lagos   6500000         0
# 27                                  Ikate Lekki Lagos   5000000         1
# 28                        Oniru Victoria Island Lagos   7000000         0
# 29                         Megamond Ikota Lekki Lagos   8000000         0
# 30                                  Ikota Lekki Lagos   3500000         1
# 31                                 Orchid Lekki Lagos   3500000         1
# 32                                  Ikate Lekki Lagos   5500000         1
# 33           Off 3rd Avenue Banana Island Ikoyi Lagos  17000000         1
# 34                        Oniru Victoria Island Lagos   6500000         1
# 35                                  Ikate Lekki Lagos  58000000         0
# 36                                Jakande Lekki Lagos   7000000         1
# 37                                  Ikota Lekki Lagos   4000000         0
# 38                          Lekki Phase 1 Lekki Lagos   8000000         1
# 39                                Chevron Lekki Lagos   5000000         0
# 40                           Osapa London Lekki Lagos   5500000         1
# 41                                  Ikate Lekki Lagos   8500000         1
# 42                          Lekki Phase 1 Lekki Lagos   8000000         0
# 43            Off Admiralty Lekki Phase 1 Lekki Lagos  15000000         0
# 44                          Lekki Phase 1 Lekki Lagos  13000000         1
# 45                           Osapa London Lekki Lagos   6500000         1
# 46                          Lekki Phase 1 Lekki Lagos   8000000         1
# 47                                Ologolo Lekki Lagos   3000000         0
# 48                                  Ikate Lekki Lagos   4000000         1
# 49                          Banana Island Ikoyi Lagos  15000000         1
#
#     Newly Built  Furnished  Bedrooms  Bathrooms  Toilets    city  state  \
# 0             1          0         4          4        5   Lekki  Lagos
# 1             1          0         4          4        5   Lekki  Lagos
# 2             0          0         2          3        3   Lekki  Lagos
# 3             1          0         2          3        3   Lekki  Lagos
# 4             1          0         2          3        3   Ikoyi  Lagos
# 5             0          0         4          5        5   Lekki  Lagos
# 6             0          0         3          4        4   Ikoyi  Lagos
# 7             0          0         3          4        4   Ikoyi  Lagos
# 8             1          0         3          3        4   Lekki  Lagos
# 9             1          0         5          5        5    Ajah  Lagos
# 10            0          0         5          5        6   Ikoyi  Lagos
# 11            0          1         5          6        7   Lekki  Lagos
# 12            1          0         3          3        4    Ajah  Lagos
# 13            1          0         5          6        6   Lekki  Lagos
# 14            1          1         2          2        2   Lekki  Lagos
# 15            0          0         4          5        5   Lekki  Lagos
# 16            1          0         4          5        5   Lekki  Lagos
# 17            1          0         3          4        4  Island  Lagos
# 18            0          0         4          4        5   Lekki  Lagos
# 19            0          0         3          3        4   Ikoyi  Lagos
# 20            0          0         0          0        0    Yaba  Lagos
# 21            1          0         3          4        4   Lekki  Lagos
# 22            0          0         1          1        1   Lekki  Lagos
# 23            1          0         1          2        2    Yaba  Lagos
# 24            1          0         2          3        3    Yaba  Lagos
# 25            0          0         3          3        4   Lekki  Lagos
# 26            1          0         4          4        5   Lekki  Lagos
# 27            1          0         2          2        3   Lekki  Lagos
# 28            0          0         5          5        6  Island  Lagos
# 29            1          0         5          5        6   Lekki  Lagos
# 30            0          0         3          3        4   Lekki  Lagos
# 31            1          0         4          4        5   Lekki  Lagos
# 32            1          0         2          2        3   Lekki  Lagos
# 33            1          0         3          3        4   Ikoyi  Lagos
# 34            0          0         3          3        4  Island  Lagos
# 35            1          0         2          2        3   Lekki  Lagos
# 36            1          0         4          4        5   Lekki  Lagos
# 37            1          0         4          4        5   Lekki  Lagos
# 38            0          0         4          4        5   Lekki  Lagos
# 39            1          0         4          4        5   Lekki  Lagos
# 40            1          0         4          4        5   Lekki  Lagos
# 41            1          0         4          4        5   Lekki  Lagos
# 42            0          0         4          4        5   Lekki  Lagos
# 43            0          0         6          6        6   Lekki  Lagos
# 44            1          0         3          3        4   Lekki  Lagos
# 45            1          0         4          4        5   Lekki  Lagos
# 46            0          0         4          4        5   Lekki  Lagos
# 47            1          0         3          3        4   Lekki  Lagos
# 48            1          0         3          3        4   Lekki  Lagos
# 49            1          0         3          3        4   Ikoyi  Lagos
#
#              Area
# 0          Agungi
# 1             VGC
# 2    Osapa London
# 3         Ologolo
# 4           Ikoyi
# 5         Chevron
# 6           Ikoyi
# 7           Ikoyi
# 8         Chevron
# 9            Ajah
# 10          Ikoyi
# 11  Admiralty way
# 12           Ajah
# 13         Agungi
# 14          Ikate
# 15        Chevron
# 16   Osapa London
# 17             VI
# 18            NaN
# 19          Ikoyi
# 20          Onike
# 21        Chevron
# 22  Lekki Phase 1
# 23      Abule Oja
# 24          Onike
# 25  Lekki Phase 1
# 26        Chevron
# 27          Ikate
# 28             VI
# 29          Ikota
# 30          Ikota
# 31         Orchid
# 32          Ikate
# 33          Ikoyi
# 34             VI
# 35          Ikate
# 36        Jakande
# 37          Ikota
# 38  Lekki Phase 1
# 39        Chevron
# 40   Osapa London
# 41          Ikate
# 42  Lekki Phase 1
# 43  Lekki Phase 1
# 44  Lekki Phase 1
# 45   Osapa London
# 46  Lekki Phase 1
# 47        Ologolo
# 48          Ikate
# 49          Ikoyi

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Grouping the cities by the average prices
cities = Rentaldata.groupby('city')['Price'].mean().round(2).sort_values(ascending= False).reset_index()

#Visualizing the cities
plt.figure(figsize=(10, 6))
sns.barplot(x='city', y='Price', data= cities, color='Orange')

# Customize the plot
plt.xlabel('cities')
plt.ylabel('Prices')
plt.title('Average cost of rent in various cities in lagos')

# Show the plot
plt.show()

# %%
Rentaldata['Area'].unique()
# Out:
# array(['Agungi', 'VGC', 'Osapa London', 'Ologolo', 'Ikoyi', 'Chevron',
#        'Ajah', 'Admiralty way', 'Ikate', 'VI', nan, 'Onike',
#        'Lekki Phase 1', 'Abule Oja', 'Ikota', 'Orchid', 'Jakande',
#        'Estate', 'Idado', 'Akoka', 'Opebi', 'Adekunle', 'Egbe', 'Kusenla',
#        'Lekki Phase 2', 'Surulere', 'Chevron Drive', 'Fola Agoro',
#        'Gbagada', 'Ebute metta', 'Isolo', 'Ikate Elegushi', 'Ojo',
#        'Okota', 'Ayobo', 'Sangotedo', 'Ogba', 'Iba', 'Igbo Efon',
#        'Obanikoro', 'Ilupeju', 'Amuwo Odofin', 'Alimosho', 'Aguda',
#        'kosofe', 'Iwaya', 'Baruwa', 'Alagomeji', 'Alapere', 'Marwa',
#        'Ikorodu', 'Onipanu', 'Second toll gate', 'Peace estate',
#        'Abule Egba', 'Aboru', 'Salem', 'Agege', 'Alagbado', 'Isheri',
#        'Ifako Gbagada', 'bawala', 'Ikotun', '2nd toll gate',
#        'Adeniyi Jones', 'Maryland', 'Lekki right', 'Ilasan', 'Ogudu GRA',
#        'LBS', 'New road', 'Jibowu', 'command', 'Chevy View Estate',
#        'Oregun', 'Ikeja GRA', 'Freedom Way', 'Anthony village',
#        'bajulaiye', 'Cement', 'shangisha', 'Tejuosho', 'Ketu',
#        'Palmgroove', 'Sholuyi', 'Mushin', 'Omole Phase 1', 'Ijesha',
#        'Oshodi', 'Ikeja Along', 'Awoyaya', 'Orile', 'Mile 12', 'Alausa',
#        'Ejigbo', 'Allen avenue', 'Magodo Phase 1', 'Chisco Ikate',
#        'Ibeju Lekki', 'Ilaje', 'Oniru', 'Ikosi Ketu', 'Akin Adesola VI',
#        'Nike Art Gallery', 'Deeper life', 'Bode Thomas', 'Makoko',
#        'Iyana paja', 'Apapa', 'Omole Phase2', 'Lakowe', 'Lagos island',
#        'Berger', 'coker', 'Ado', 'Abesan', 'Ota', 'Magodo phase 2',
#        'Olowora', 'Alaguntan', 'Mile 2', 'Waec', 'Morroco', 'Eleko',
#        'Badagry', 'Kudirat Abiola way', 'Obawole', 'Alaba',
#        'Magodo shangisha', 'Opic', 'Ebute', 'Elf', 'Ogombo',
#        'Ogudu Ori Oke', 'Banana Island', 'Gbagada phase 2', 'Owode',
#        'Alhaja', 'Epe', 'Okokomaiko', 'Allen ikeja', 'Festac town',
#        'Agboyi', 'Obalende', 'Majek', 'Pipeline', 'Ifako Ijaiye',
#        'Oke Ira', 'Ogunlana drive', 'lagos Mainland'], dtype=object)

# %%
Rentaldata.drop(columns = ['Unnamed: 0.1','Unnamed: 0', 'city','state'], axis = 1, inplace =True)

# %%
Rentaldata.isnull().sum()
# Out:
# Location          0
# Price             0
# Serviced          0
# Newly Built       0
# Furnished         0
# Bedrooms          0
# Bathrooms         0
# Toilets           0
# Area           4804
# dtype: int64

# %%
Rentaldata.dropna(axis = 0, inplace = True)

# %% [markdown]
# removing outliers

# %%
main = Rentaldata.query("Price > 200000")

# %%
main.describe()
# Out:
#               Price      Serviced   Newly Built     Furnished      Bedrooms  \
# count  6.694600e+04  66946.000000  66946.000000  66946.000000  66946.000000
# mean   3.413109e+07      0.178562      0.300630      0.132211      2.337944
# std    6.572985e+09      0.382988      0.458536      0.338723      1.385888
# min    2.000090e+05      0.000000      0.000000      0.000000      0.000000
# 25%    7.000000e+05      0.000000      0.000000      0.000000      1.000000
# 50%    1.500000e+06      0.000000      0.000000      0.000000      2.000000
# 75%    3.500000e+06      0.000000      1.000000      0.000000      3.000000
# max    1.700000e+12      1.000000      1.000000      1.000000     10.000000
#
#           Bathrooms       Toilets
# count  66946.000000  66946.000000
# mean       2.209915      2.598124
# std        1.553964      1.822122
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        2.000000      3.000000
# 75%        3.000000      4.000000
# max       10.000000     10.000000

# %%
main
# Out:
#                                                 Location    Price  Serviced  \
# 0      White Oak Estate, Ologolo Opp. Agungi, Ologolo...  5000000         0
# 1          Hrc Estate Beside Vgc Estate, Vgc Lekki Lagos  5000000         0
# 2                               Osapa London Lekki Lagos  3500000         1
# 3                                    Ologolo Lekki Lagos  2700000         1
# 4                           Mojisola Onikoyi Ikoyi Lagos  5000000         1
# ...                                                  ...      ...       ...
# 73229  No.3, Alice Ogunsona Stt, Hilltop Estate, Off ...   300000         0
# 73230             Behind Romay Garden Ilasan Lekki Lagos  1200000         0
# 73231                             Ikate Area Lekki Lagos  4500000         0
# 73232               Onipetesi Estate Mangoro Ikeja Lagos   400000         0
# 73233                   Oluwaga Road. Baruwa Ipaja Lagos   500000         0
#
#        Newly Built  Furnished  Bedrooms  Bathrooms  Toilets          Area
# 0                1          0         4          4        5        Agungi
# 1                1          0         4          4        5           VGC
# 2                0          0         2          3        3  Osapa London
# 3                1          0         2          3        3       Ologolo
# 4                1          0         2          3        3         Ikoyi
# ...            ...        ...       ...        ...      ...           ...
# 73229            0          0         3          2        3       Ikorodu
# 73230            0          0         2          3        3        Ilasan
# 73231            1          1         5          6        6         Ikate
# 73232            0          0         1          1        1        Estate
# 73233            1          1         3          4        4        Baruwa
#
# [66946 rows x 9 columns]

# %%
df = main.copy

# %%
def remove_outlier(data):
    '''
    This function returns the total outliers in a dataset column, and replaces the upper and lower outliers
    using the Interquartile Range (IQR) Method.
    data = df['columns']
    '''
    #calculationg the third quartile of the column
    Q3 = data.quantile(0.75)

    #Calculating the First quartile of the column
    Q1 = data.quantile(0.25)

    #Calculating the Interquartile range
    IQR = Q3 - Q1

    # Identifying the lower outliers
    lower_limit = round(Q1 - 1.5 * IQR)

    #Identifying the upper outliers
    upper_limit = round(Q3 + 1.5 * IQR)

    #Replacing the lower outliers with the lower IQR value
    data.loc[data> upper_limit] = upper_limit

    #Replacing the upper outliers with the lower IQR value
    data.loc[data<lower_limit] = lower_limit

    return data

# %%
main['Price'].max()
# Out:
# 1700000000000

# %%
#Removing the outliers in each column. 
main['Price'] = remove_outlier(main['Price'])
main['Bedrooms'] = remove_outlier(main['Bedrooms'])
main['Bathrooms'] = remove_outlier(main['Bathrooms'])
main['Toilets'] = remove_outlier(main['Toilets'])

#Taking out rows with unrealistic prices
Too_cheap_price = main[(main['Price'] <100000)].index
main = main.drop(Too_cheap_price, axis=0)
main.head()
# Out:
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data> upper_limit] = upper_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data<lower_limit] = lower_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\252131334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main['Price'] = remove_outlier(main['Price'])
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data> upper_limit] = upper_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data<lower_limit] = lower_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\252131334.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main['Bedrooms'] = remove_outlier(main['Bedrooms'])
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data> upper_limit] = upper_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data<lower_limit] = lower_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\252131334.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main['Bathrooms'] = remove_outlier(main['Bathrooms'])
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data> upper_limit] = upper_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\402453779.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data<lower_limit] = lower_limit
# C:\Users\faniy\AppData\Local\Temp\ipykernel_14620\252131334.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main['Toilets'] = remove_outlier(main['Toilets'])
#                                             Location    Price  Serviced  \
# 0  White Oak Estate, Ologolo Opp. Agungi, Ologolo...  5000000         0
# 1      Hrc Estate Beside Vgc Estate, Vgc Lekki Lagos  5000000         0
# 2                           Osapa London Lekki Lagos  3500000         1
# 3                                Ologolo Lekki Lagos  2700000         1
# 4                       Mojisola Onikoyi Ikoyi Lagos  5000000         1
#
#    Newly Built  Furnished  Bedrooms  Bathrooms  Toilets          Area
# 0            1          0         4          4        5        Agungi
# 1            1          0         4          4        5           VGC
# 2            0          0         2          3        3  Osapa London
# 3            1          0         2          3        3       Ologolo
# 4            1          0         2          3        3         Ikoyi

# %%
main.describe()
# Out:
#               Price      Serviced   Newly Built     Furnished      Bedrooms  \
# count  6.694600e+04  66946.000000  66946.000000  66946.000000  66946.000000
# mean   2.498423e+06      0.178562      0.300630      0.132211      2.329923
# std    2.361048e+06      0.382988      0.458536      0.338723      1.355250
# min    2.000090e+05      0.000000      0.000000      0.000000      0.000000
# 25%    7.000000e+05      0.000000      0.000000      0.000000      1.000000
# 50%    1.500000e+06      0.000000      0.000000      0.000000      2.000000
# 75%    3.500000e+06      0.000000      1.000000      0.000000      3.000000
# max    7.700000e+06      1.000000      1.000000      1.000000      6.000000
#
#           Bathrooms       Toilets
# count  66946.000000  66946.000000
# mean       2.202282      2.595286
# std        1.527778      1.812244
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        2.000000      3.000000
# 75%        3.000000      4.000000
# max        6.000000      8.000000

# %%
main
# Out:
#                                                 Location    Price  Serviced  \
# 0      White Oak Estate, Ologolo Opp. Agungi, Ologolo...  5000000         0
# 1          Hrc Estate Beside Vgc Estate, Vgc Lekki Lagos  5000000         0
# 2                               Osapa London Lekki Lagos  3500000         1
# 3                                    Ologolo Lekki Lagos  2700000         1
# 4                           Mojisola Onikoyi Ikoyi Lagos  5000000         1
# ...                                                  ...      ...       ...
# 73229  No.3, Alice Ogunsona Stt, Hilltop Estate, Off ...   300000         0
# 73230             Behind Romay Garden Ilasan Lekki Lagos  1200000         0
# 73231                             Ikate Area Lekki Lagos  4500000         0
# 73232               Onipetesi Estate Mangoro Ikeja Lagos   400000         0
# 73233                   Oluwaga Road. Baruwa Ipaja Lagos   500000         0
#
#        Newly Built  Furnished  Bedrooms  Bathrooms  Toilets          Area
# 0                1          0         4          4        5        Agungi
# 1                1          0         4          4        5           VGC
# 2                0          0         2          3        3  Osapa London
# 3                1          0         2          3        3       Ologolo
# 4                1          0         2          3        3         Ikoyi
# ...            ...        ...       ...        ...      ...           ...
# 73229            0          0         3          2        3       Ikorodu
# 73230            0          0         2          3        3        Ilasan
# 73231            1          1         5          6        6         Ikate
# 73232            0          0         1          1        1        Estate
# 73233            1          1         3          4        4        Baruwa
#
# [66946 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()

def encode(df):
    for i in df.columns:
        if df[i].dtype == 'object':
            df[i] = lb.fit_transform(df[i])

# %%
encode(main)

# %%
main
# Out:
#        Location    Price  Serviced  Newly Built  Furnished  Bedrooms  \
# 0         19710  5000000         0            1          0         4
# 1          7939  5000000         0            1          0         4
# 2         16490  3500000         1            0          0         2
# 3         15378  2700000         1            1          0         2
# 4         11463  5000000         1            1          0         2
# ...         ...      ...       ...          ...        ...       ...
# 73229     11903   300000         0            0          0         3
# 73230      4204  1200000         0            0          0         2
# 73231      8311  4500000         0            1          1         5
# 73232     15916   400000         0            0          0         1
# 73233     15608   500000         0            1          1         3
#
#        Bathrooms  Toilets  Area
# 0              4        5    12
# 1              4        5   138
# 2              3        3   125
# 3              3        3   113
# 4              3        3    69
# ...          ...      ...   ...
# 73229          2        3    65
# 73230          3        3    71
# 73231          6        6    61
# 73232          1        1    49
# 73233          4        4    33
#
# [66946 rows x 9 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()

def scaler(df):
    for i in df.columns:
        df[[i]] = mm.fit_transform(df[[i]])

# %%
main
# Out:
#        Location    Price  Serviced  Newly Built  Furnished  Bedrooms  \
# 0         19710  5000000         0            1          0         4
# 1          7939  5000000         0            1          0         4
# 2         16490  3500000         1            0          0         2
# 3         15378  2700000         1            1          0         2
# 4         11463  5000000         1            1          0         2
# ...         ...      ...       ...          ...        ...       ...
# 73229     11903   300000         0            0          0         3
# 73230      4204  1200000         0            0          0         2
# 73231      8311  4500000         0            1          1         5
# 73232     15916   400000         0            0          0         1
# 73233     15608   500000         0            1          1         3
#
#        Bathrooms  Toilets  Area
# 0              4        5    12
# 1              4        5   138
# 2              3        3   125
# 3              3        3   113
# 4              3        3    69
# ...          ...      ...   ...
# 73229          2        3    65
# 73230          3        3    71
# 73231          6        6    61
# 73232          1        1    49
# 73233          4        4    33
#
# [66946 rows x 9 columns]

# %%
x = main.drop(['Price', 'Location'], axis = 1)
y = main['Price']

# %%
x
# Out:
#        Serviced  Newly Built  Furnished  Bedrooms  Bathrooms  Toilets  Area
# 0             0            1          0         4          4        5    12
# 1             0            1          0         4          4        5   138
# 2             1            0          0         2          3        3   125
# 3             1            1          0         2          3        3   113
# 4             1            1          0         2          3        3    69
# ...         ...          ...        ...       ...        ...      ...   ...
# 73229         0            0          0         3          2        3    65
# 73230         0            0          0         2          3        3    71
# 73231         0            1          1         5          6        6    61
# 73232         0            0          0         1          1        1    49
# 73233         0            1          1         3          4        4    33
#
# [66946 rows x 7 columns]

# %%
scaler(x)

# %%
x.columns
# Out:
# Index(['Serviced', 'Newly Built', 'Furnished', 'Bedrooms', 'Bathrooms',
#        'Toilets', 'Area'],
#       dtype='object')

# %%
x
# Out:
#        Serviced  Newly Built  Furnished  Bedrooms  Bathrooms  Toilets  \
# 0           0.0          1.0        0.0  0.666667   0.666667    0.625
# 1           0.0          1.0        0.0  0.666667   0.666667    0.625
# 2           1.0          0.0        0.0  0.333333   0.500000    0.375
# 3           1.0          1.0        0.0  0.333333   0.500000    0.375
# 4           1.0          1.0        0.0  0.333333   0.500000    0.375
# ...         ...          ...        ...       ...        ...      ...
# 73229       0.0          0.0        0.0  0.500000   0.333333    0.375
# 73230       0.0          0.0        0.0  0.333333   0.500000    0.375
# 73231       0.0          1.0        1.0  0.833333   1.000000    0.750
# 73232       0.0          0.0        0.0  0.166667   0.166667    0.125
# 73233       0.0          1.0        1.0  0.500000   0.666667    0.500
#
#            Area
# 0      0.081633
# 1      0.938776
# 2      0.850340
# 3      0.768707
# 4      0.469388
# ...         ...
# 73229  0.442177
# 73230  0.482993
# 73231  0.414966
# 73232  0.333333
# 73233  0.224490
#
# [66946 rows x 7 columns]

# %%
y
# Out:
# 0        5000000
# 1        5000000
# 2        3500000
# 3        2700000
# 4        5000000
#           ...
# 73229     300000
# 73230    1200000
# 73231    4500000
# 73232     400000
# 73233     500000
# Name: Price, Length: 66946, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators = 198, max_features = 15, max_depth = None, min_samples_split = 10)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_features=15, min_samples_split=10, n_estimators=198)

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_train, y_train)
# Out:
# 0.8194275627555803

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mae = mean_absolute_error(y_pred, y_test)
mae
# Out:
# 691085.949851657

# %%
x
# Out:
#        Serviced  Newly Built  Furnished  Bedrooms  Bathrooms  Toilets  \
# 0           0.0          1.0        0.0  0.666667   0.666667    0.625
# 1           0.0          1.0        0.0  0.666667   0.666667    0.625
# 2           1.0          0.0        0.0  0.333333   0.500000    0.375
# 3           1.0          1.0        0.0  0.333333   0.500000    0.375
# 4           1.0          1.0        0.0  0.333333   0.500000    0.375
# ...         ...          ...        ...       ...        ...      ...
# 73229       0.0          0.0        0.0  0.500000   0.333333    0.375
# 73230       0.0          0.0        0.0  0.333333   0.500000    0.375
# 73231       0.0          1.0        1.0  0.833333   1.000000    0.750
# 73232       0.0          0.0        0.0  0.166667   0.166667    0.125
# 73233       0.0          1.0        1.0  0.500000   0.666667    0.500
#
#            Area
# 0      0.081633
# 1      0.938776
# 2      0.850340
# 3      0.768707
# 4      0.469388
# ...         ...
# 73229  0.442177
# 73230  0.482993
# 73231  0.414966
# 73232  0.333333
# 73233  0.224490
#
# [66946 rows x 7 columns]

# %%
y_test
# Out:
# 56780    3500000
# 64117     900000
# 20360    6500000
# 51105     600000
# 50322    7700000
#           ...
# 35891    7000000
# 38270     500000
# 60449     250000
# 68651    1000000
# 37395    2000000
# Name: Price, Length: 13390, dtype: int64

# %%
y_test
# Out:
# 56780    3500000
# 64117     900000
# 20360    6500000
# 51105     600000
# 50322    7700000
#           ...
# 35891    7000000
# 38270     500000
# 60449     250000
# 68651    1000000
# 37395    2000000
# Name: Price, Length: 13390, dtype: int64

# %%
x
# Out:
#        Serviced  Newly Built  Furnished  Bedrooms  Bathrooms  Toilets  \
# 0           0.0          1.0        0.0  0.666667   0.666667    0.625
# 1           0.0          1.0        0.0  0.666667   0.666667    0.625
# 2           1.0          0.0        0.0  0.333333   0.500000    0.375
# 3           1.0          1.0        0.0  0.333333   0.500000    0.375
# 4           1.0          1.0        0.0  0.333333   0.500000    0.375
# ...         ...          ...        ...       ...        ...      ...
# 73229       0.0          0.0        0.0  0.500000   0.333333    0.375
# 73230       0.0          0.0        0.0  0.333333   0.500000    0.375
# 73231       0.0          1.0        1.0  0.833333   1.000000    0.750
# 73232       0.0          0.0        0.0  0.166667   0.166667    0.125
# 73233       0.0          1.0        1.0  0.500000   0.666667    0.500
#
#            Area
# 0      0.081633
# 1      0.938776
# 2      0.850340
# 3      0.768707
# 4      0.469388
# ...         ...
# 73229  0.442177
# 73230  0.482993
# 73231  0.414966
# 73232  0.333333
# 73233  0.224490
#
# [66946 rows x 7 columns]

# %%
predictions = pd.DataFrame({'Actual Values': y_test, 'Predicted Values': y_pred})
predictions
# Out:
#        Actual Values  Predicted Values
# 56780        3500000      4.385163e+06
# 64117         900000      8.052662e+05
# 20360        6500000      5.240357e+06
# 51105         600000      7.919499e+05
# 50322        7700000      7.569572e+06
# ...              ...               ...
# 35891        7000000      6.892249e+06
# 38270         500000      5.426956e+05
# 60449         250000      3.352500e+05
# 68651        1000000      1.890642e+06
# 37395        2000000      1.454552e+06
#
# [13390 rows x 2 columns]

# %%
from joblib import dump

# %%
dump(model, 'Price.joblib')
# Out:
# ['Price.joblib']

# %%
import pickle

# %%
with open('Price.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
x
# Out:
#        Serviced  Newly Built  Furnished  Bedrooms  Bathrooms  Toilets  \
# 0           0.0          1.0        0.0  0.666667   0.666667    0.625
# 1           0.0          1.0        0.0  0.666667   0.666667    0.625
# 2           1.0          0.0        0.0  0.333333   0.500000    0.375
# 3           1.0          1.0        0.0  0.333333   0.500000    0.375
# 4           1.0          1.0        0.0  0.333333   0.500000    0.375
# ...         ...          ...        ...       ...        ...      ...
# 73229       0.0          0.0        0.0  0.500000   0.333333    0.375
# 73230       0.0          0.0        0.0  0.333333   0.500000    0.375
# 73231       0.0          1.0        1.0  0.833333   1.000000    0.750
# 73232       0.0          0.0        0.0  0.166667   0.166667    0.125
# 73233       0.0          1.0        1.0  0.500000   0.666667    0.500
#
#            Area
# 0      0.081633
# 1      0.938776
# 2      0.850340
# 3      0.768707
# 4      0.469388
# ...         ...
# 73229  0.442177
# 73230  0.482993
# 73231  0.414966
# 73232  0.333333
# 73233  0.224490
#
# [66946 rows x 7 columns]

# %%
y_pred_new = model.predict([[0.0,	1.0,0.0,	0.666667,	0.666667,	0.625,	0.081633]])
# Out:
# c:\Users\faniy\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
y_pred_new
# Out:
# array([4473345.01713693])

# %%
model2 = LinearRegression()
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred2 = model2.predict(x_test)
y_pred2
# Out:
# array([ 0.56090342,  0.3501196 ,  0.60895431, ..., -0.04229496,
#         0.34114955,  0.26013874])

# %%
predictions = pd.DataFrame({'Actual Values': y_test, 'Predicted Values': y_pred})
predictions
# Out:
#        Actual Values  Predicted Values
# 0           0.439999          0.564677
# 1           0.093332          0.080860
# 2           0.840000          0.669407
# 3           0.053332          0.079254
# 4           1.000000          0.982300
# ...              ...               ...
# 13385       0.906667          0.891246
# 13386       0.039999          0.048041
# 13387       0.006665          0.018640
# 13388       0.106666          0.223558
# 13389       0.239999          0.158410
#
# [13390 rows x 2 columns]

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 1129486.269379362

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.022772424491822665

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 0.15090534944733625

# %%
from sklearn.metrics import r2_score

rsquared = r2_score(y_pred, y_test)
rsquared
# Out:
# 0.7163537328524658
